# %% [markdown]
# # Data Visualization:
#
# ### Generate data visualizations, including histograms, scatter plots, and box plots, to reveal data distribution and patterns.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\sajee\Internship file folder\DataScience\DataVisualization\Bengaluru_House_Data.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
# histogram using matplotlib

# fig, ax = plt.subplots(figsize=(6,6))
# plt.hist(df['price'], bins=15 , color= 'r')
# plt.title('histogram of price using matplotlib')
# plt.xlabel("value")
# plt.ylabel("price")
# plt.show()

# histogram using seaborn

sns.set (style='ticks', palette = 'deep', font_scale=1.1)
plt.hist(df['price'], bins=15 , color= 'b')
plt.title('histogram of price using seaborn')
plt.xlabel("value")
plt.ylabel("price")
plt.show()

# %%
# scatter using matplotlib

# fig, ax = plt.subplots(figsize=(8,8))
# scatter = ax.scatter(df['price'], df['bath'], s=50, c='b', alpha=0.6, edgecolors='w', linewidth=0.5 )
# plt.title('scatterplot of price and bath using matplotlib')
# plt.xlabel("price")
# plt.ylabel("bath")
# plt.show()

# scatter using seaborn

# sns.set (style='ticks', palette = 'deep', font_scale=1.1)
# plt.hist(df['price'], bins=15 , color= 'b')
# plt.title('histogram of price using seaborn')
# plt.xlabel("value")
# plt.ylabel("price")
# plt.show()

# %%
# fig, ax = plt.subplots(figsize=(8, 6))
# df.boxplot(column='bath', by='price', ax=ax)

# # Set the labels and title
# ax.set_xlabel('Price')
# ax.set_ylabel('Number of Bathrooms')
# plt.title('Boxplot of Number of Bathrooms by Price')
# plt.suptitle('')  # This removes the default 'Boxplot grouped by price' title

# # Show the plot
# plt.show()

# %%
# boxplot using matplotlib 

# Filter out extreme outliers
# df_filtered = df[df['bath'] <= 10]
# df_filtered = df[df['price'] <= 10]

# # Set plot style
# sns.set(style="whitegrid")

# # Create the figure and axis
# fig, ax = plt.subplots(figsize=(10, 8))

# # Create the boxplot
# df_filtered.boxplot(column='bath', by='price', ax=ax)

# # Set the labels and title
# ax.set_xlabel('Price')
# ax.set_ylabel('Number of Bathrooms')
# plt.title('Boxplot of Number of Bathrooms by Price')
# plt.suptitle('')  # This removes the default 'Boxplot grouped by price' title

# # Use log scale for x-axis if necessary
# # ax.set_xscale('log')

# # Show the plot
# plt.show()

# %% [markdown]
# ### Create correlation matrices and heatmaps to identify relationships between variables.

# %%
df1 = df.drop(columns =['area_type','availability','location', 'size','society','total_sqft'])
df1
# Out:
#        bath  balcony   price
# 0       2.0      1.0   39.07
# 1       5.0      3.0  120.00
# 2       2.0      3.0   62.00
# 3       3.0      1.0   95.00
# 4       2.0      1.0   51.00
# ...     ...      ...     ...
# 13315   4.0      0.0  231.00
# 13316   5.0      NaN  400.00
# 13317   2.0      1.0   60.00
# 13318   4.0      1.0  488.00
# 13319   1.0      1.0   17.00
#
# [13320 rows x 3 columns]

# %%
# hep = df.loc[df.price == 'hepatitis']
corr_mat_hep = df1.corr().round(2)
corr_mat_hep
# Out:
#          bath  balcony  price
# bath     1.00     0.20   0.46
# balcony  0.20     1.00   0.12
# price    0.46     0.12   1.00

# %%
plt.figure(figsize=(6,6))
plot = sns.heatmap(df1.corr().round(2), annot = True)

# %% [markdown]
# # Descriptive Statistics:
#
# ### Calculate summary statistics, such as mean, median, and standard deviation, to describe data central tendencies and variability.

# %%
df.describe(include='all')
# Out:
#                    area_type   availability    location   size  society  \
# count                  13320          13320       13319  13304     7818
# unique                     4             81        1305     31     2688
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK  GrrvaGr
# freq                    8790          10581         540   5199       80
# mean                     NaN            NaN         NaN    NaN      NaN
# std                      NaN            NaN         NaN    NaN      NaN
# min                      NaN            NaN         NaN    NaN      NaN
# 25%                      NaN            NaN         NaN    NaN      NaN
# 50%                      NaN            NaN         NaN    NaN      NaN
# 75%                      NaN            NaN         NaN    NaN      NaN
# max                      NaN            NaN         NaN    NaN      NaN
#
#        total_sqft          bath       balcony         price
# ...

# %% [markdown]
# ### Explore data distributions and assess skewness and kurtosis.

# %%
# skew 
df['price'].skew()
# Out:
# 8.064468821273252

# %%
# kurtosis

df['price'].kurtosis()
# Out:
# 108.16651274550613

# %% [markdown]
# ### Outlier

# %%
# Assuming 'df' is your DataFrame
sns.displot(df['bath'], kde=True)
plt.xlabel('Number of Bathrooms')
plt.ylabel('Density')
plt.title('Distribution of Number of Bathrooms')
plt.show()
# Out:
# C:\Users\sajee\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(df['bath'])
# Out:
# <Axes: >

# %%
upper_limit = df['bath'].mean() + 3* df['bath'].std()
lower_limit = df['bath'].mean() - 3* df['bath'].std()
print("upper_limit" , upper_limit)
print("lower_limit" , lower_limit)
# Out:
# upper_limit 6.716983881840704
# lower_limit -1.3317645869060022

# %%
df.loc[(df['bath'] > upper_limit) | (df['bath'] <lower_limit)]
# Out:
#             area_type   availability               location       size  \
# 45         Plot  Area  Ready To Move             HSR Layout  8 Bedroom
# 64     Built-up  Area  Ready To Move           Bommanahalli  8 Bedroom
# 68         Plot  Area  Ready To Move    Devarachikkanahalli  8 Bedroom
# 85     Built-up  Area  Ready To Move            Hegde Nagar  6 Bedroom
# 129        Plot  Area  Ready To Move     Vishwapriya Layout  7 Bedroom
# ...               ...            ...                    ...        ...
# 13219      Plot  Area  Ready To Move                Laggere  7 Bedroom
# 13221      Plot  Area  Ready To Move          T Dasarahalli  9 Bedroom
# 13226  Built-up  Area  Ready To Move  Raja Rajeshwari Nagar  8 Bedroom
# 13277      Plot  Area  Ready To Move    Kundalahalli Colony  7 Bedroom
# 13311      Plot  Area  Ready To Move       Ramamurthy Nagar  7 Bedroom
#
#       society total_sqft  bath  balcony  price
# 45        NaN        600   9.0      NaN  200.0
# ...

# %%
new_df = df.loc[(df['bath'] > upper_limit) | (df['bath'] <lower_limit)]
print("old data" , len(df))
print("new data", len(new_df))
# Out:
# old data 13320
# new data 242
